# %% [markdown]
# **Data Acquisition**

# %%
import requests
import pandas as pd

CONSUMER_KEY = "iUVMuMJVhEVIUiXffobo"
CONSUMER_SECRET = "skUDuDoftPUWCwqSszhVHmnimkycJdyV"

BASE_URL = "https://api.discogs.com/database/search"
HEADERS = {
    "User-Agent": "MyDiscogsClient/1.0"
}

all_records = []  

for page in range(1, 11):
    params = {
        "key": CONSUMER_KEY,
        "secret": CONSUMER_SECRET,
        "type": "release",
        "per_page": 50,
        "page": page,
        "sort": "year",
        "sort_order": "desc"
    }

    response = requests.get(BASE_URL, headers=HEADERS, params=params)
    response.raise_for_status()
    data = response.json()

    results = data.get("results", [])
    print(f"Page {page}: got {len(results)} records")

    for item in results:
        title = item.get("title", "")
        year = item.get("year", None)
        country = item.get("country", "")
        genre = item.get("genre", [])
        style = item.get("style", [])
        label = item.get("label", [])
        format_ = item.get("format", [])
        catno = item.get("catno", "")

        # some fields are lists → join to strings
        genre_str = ", ".join(genre) if isinstance(genre, list) else genre
        style_str = ", ".join(style) if isinstance(style, list) else style
        label_str = ", ".join(label) if isinstance(label, list) else label
        format_str = ", ".join(format_) if isinstance(format_, list) else format_

        all_records.append({
            "title": title,
            "year": year,
            "country": country,
            "genre": genre_str,
            "style": style_str,
            "label": label_str,
            "format": format_str,
            "catno": catno
        })

df = pd.DataFrame(all_records)

print("\nTotal records collected:", len(df))
print(df.head())

df
# Out:
# Page 1: got 50 records
# Page 2: got 50 records
# Page 3: got 50 records
# Page 4: got 50 records
# Page 5: got 50 records
# Page 6: got 50 records
# Page 7: got 50 records
# Page 8: got 50 records
# Page 9: got 50 records
# Page 10: got 50 records
#
# Total records collected: 500
#                                  title  year   country             genre  \
# 0  Canaan - For A Bird That Never Flew  2026     Italy        Electronic
# 1         Various - Family Trip Disc 2  2026  Portugal        Electronic
# 2      Various - Marseille VA Volume 1  2026    France        Electronic
# 3      Periode - Grapes Of Nothingness  2026   Germany  Electronic, Rock
# 4                 [ˈʌðɚ] - /ˈθɜːˈtiːn/  2026   Germany        Electronic
#
#                                      style  \
# 0                   Darkwave, Dark Ambient
# 1                House, Tech House, Breaks
# 2  Deep House, Tech House, Techno, Electro
# 3          Leftfield, Krautrock, Post-Punk
# 4                           Ambient, Drone
#
#                                                label  \
# 0  Eibon Records, Eibon Records, Kanaanian Lair, ...
# 1  Magic Carpet, Subwax Distribution, R.A.N.D. Muzik
# 2                                   Mindtrip Records
# 3  Karlrecords, Periklas Series, HeyRec.Org, HeyR...
# 4                                         ATHRSOUNDS
#
#                                         format            catno
# 0           CD, Album, Limited Edition, Stereo  CAN114 - I & II
# 1                                   Vinyl, 12"           RIDE19
# 2              Vinyl, LP, Promo, Test Pressing         MTPRLP01
# 3  Vinyl, LP, Album, Limited Edition, Numbered            KR122
# 4                  CDr, Album, Limited Edition    ATHRSOUNDS013
#                                                  title  year      country  \
# 0                  Canaan - For A Bird That Never Flew  2026        Italy
# 1                         Various - Family Trip Disc 2  2026     Portugal
# 2                      Various - Marseille VA Volume 1  2026       France
# 3                      Periode - Grapes Of Nothingness  2026      Germany
# 4                                 [ˈʌðɚ] - /ˈθɜːˈtiːn/  2026      Germany
# ..                                                 ...   ...          ...
# 495                  (T-T)b - Beautiful Extension Cord  2025           US
# 496  Sortilège - Live Bootleg - Paris - Eldorado - ...  2025      Germany
# 497                        Bryan Estepa - I See It Now  2025    Australia
# 498  Erroiak - Mordor's Dark Echoes - Ultimate Trib...  2025       France
# 499                              Molossus - This Place  2025  Netherlands
#
#                      genre                                    style  \
# 0               Electronic                   Darkwave, Dark Ambient
# 1               Electronic                House, Tech House, Breaks
# 2               Electronic  Deep House, Tech House, Techno, Electro
# 3         Electronic, Rock          Leftfield, Krautrock, Post-Punk
# 4               Electronic                           Ambient, Drone
# ..                     ...                                      ...
# 495  Electronic, Rock, Pop          Chiptune, Power Pop, Indie Rock
# 496                   Rock                              Heavy Metal
# 497                   Rock   AOR, Indie Rock, Jangle Pop, Power Pop
# 498                   Rock     Atmospheric Black Metal, Black Metal
# 499             Electronic                                 Hardcore
#
#                                                  label  \
# 0    Eibon Records, Eibon Records, Kanaanian Lair, ...
# 1    Magic Carpet, Subwax Distribution, R.A.N.D. Muzik
# 2                                     Mindtrip Records
# 3    Karlrecords, Periklas Series, HeyRec.Org, HeyR...
# 4                                           ATHRSOUNDS
# ..                                                 ...
# 495                                 Disposable America
# 496          High Roller Records, Temple Of Disharmony
# 497                                  Lilystars Records
# 498                             Ashen Cold Productions
# 499                                 The Third Movement
#
#                                                format            catno
# 0                  CD, Album, Limited Edition, Stereo  CAN114 - I & II
# 1                                          Vinyl, 12"           RIDE19
# 2                     Vinyl, LP, Promo, Test Pressing         MTPRLP01
# 3         Vinyl, LP, Album, Limited Edition, Numbered            KR122
# 4                         CDr, Album, Limited Edition    ATHRSOUNDS013
# ..                                                ...              ...
# 495                                  Vinyl, LP, Album            DA083
# 496  Vinyl, LP, Limited Edition, Numbered, Remastered          HRR 989
# 497                          Vinyl, LP, Album, Stereo          LILY158
# 498                          Box Set, Compilation, CD    ACP001-ACP002
# 499                                         File, MP3        T3RDM0446
#
# [500 rows x 8 columns]

# %% [markdown]
# **Data Cleaning**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    500 non-null    object
#  1   year     500 non-null    object
#  2   country  500 non-null    object
#  3   genre    500 non-null    object
#  4   style    500 non-null    object
#  5   label    500 non-null    object
#  6   format   500 non-null    object
#  7   catno    500 non-null    object
# dtypes: object(8)
# memory usage: 31.4+ KB

# %%
df.describe()
# Out:
#                                  title  year country genre style       label  \
# count                              500   500     500   500   500         500
# unique                             396     2      39    53   260         376
# top     Sirocco Bros* - The Wicker Man  2025      US  Rock        ATHRSOUNDS
# freq                                 2   415      93   222    55          18
#
#                   format catno
# count                500   500
# unique               180   343
# top     Vinyl, LP, Album  none
# freq                  39    61

# %%
df.shape
# Out:
# (443, 8)

# %%
df.isnull().sum()
df.dropna(inplace=True)
df.isnull().sum()
# finding and handling missing values
# Out:
# title      0
# year       0
# country    0
# genre      0
# style      0
# label      0
# format     0
# catno      0
# dtype: int64

# %%
type(df.iloc[3,:]['style']) # don't have missing value because they're considered as empty string
# Out:
# str

# %%
# drop rows where any column has empty string 
df = df[(df != "").all(axis=1)]
df
# Out:
#                                                  title  year      country  \
# 0                  Canaan - For A Bird That Never Flew  2026        Italy
# 1                         Various - Family Trip Disc 2  2026     Portugal
# 2                      Various - Marseille VA Volume 1  2026       France
# 3                      Periode - Grapes Of Nothingness  2026      Germany
# 4                                 [ˈʌðɚ] - /ˈθɜːˈtiːn/  2026      Germany
# ..                                                 ...   ...          ...
# 495                  (T-T)b - Beautiful Extension Cord  2025           US
# 496  Sortilège - Live Bootleg - Paris - Eldorado - ...  2025      Germany
# 497                        Bryan Estepa - I See It Now  2025    Australia
# 498  Erroiak - Mordor's Dark Echoes - Ultimate Trib...  2025       France
# 499                              Molossus - This Place  2025  Netherlands
#
#                      genre                                    style  \
# 0               Electronic                   Darkwave, Dark Ambient
# 1               Electronic                House, Tech House, Breaks
# 2               Electronic  Deep House, Tech House, Techno, Electro
# 3         Electronic, Rock          Leftfield, Krautrock, Post-Punk
# 4               Electronic                           Ambient, Drone
# ..                     ...                                      ...
# 495  Electronic, Rock, Pop          Chiptune, Power Pop, Indie Rock
# 496                   Rock                              Heavy Metal
# 497                   Rock   AOR, Indie Rock, Jangle Pop, Power Pop
# 498                   Rock     Atmospheric Black Metal, Black Metal
# 499             Electronic                                 Hardcore
#
#                                                  label  \
# 0    Eibon Records, Eibon Records, Kanaanian Lair, ...
# 1    Magic Carpet, Subwax Distribution, R.A.N.D. Muzik
# 2                                     Mindtrip Records
# 3    Karlrecords, Periklas Series, HeyRec.Org, HeyR...
# 4                                           ATHRSOUNDS
# ..                                                 ...
# 495                                 Disposable America
# 496          High Roller Records, Temple Of Disharmony
# 497                                  Lilystars Records
# 498                             Ashen Cold Productions
# 499                                 The Third Movement
#
#                                                format            catno
# 0                  CD, Album, Limited Edition, Stereo  CAN114 - I & II
# 1                                          Vinyl, 12"           RIDE19
# 2                     Vinyl, LP, Promo, Test Pressing         MTPRLP01
# 3         Vinyl, LP, Album, Limited Edition, Numbered            KR122
# 4                         CDr, Album, Limited Edition    ATHRSOUNDS013
# ..                                                ...              ...
# 495                                  Vinyl, LP, Album            DA083
# 496  Vinyl, LP, Limited Edition, Numbered, Remastered          HRR 989
# 497                          Vinyl, LP, Album, Stereo          LILY158
# 498                          Box Set, Compilation, CD    ACP001-ACP002
# 499                                         File, MP3        T3RDM0446
#
# [443 rows x 8 columns]

# %%
# identify duplicates
df.duplicated().value_counts()
# Out:
# False    426
# True      17
# Name: count, dtype: int64

# %%
df[df.duplicated()]
# we can see we have some duplicates in year, country, format,...
# Out:
#                                                  title  year      country  \
# 250                           Tree (17) - WE Grown NOW  2025  Netherlands
# 251            Mirrored Daughters - Mirrored Daughters  2025           UK
# 252                     Sirocco Bros* - The Wicker Man  2025           UK
# 253                        ALARM! - Heavy On The Heart  2025       Sweden
# 254                  Feeling B - Wir Kriegen Euch Alle  2025      Germany
# 255                             Hysta & Promo - Danger  2025  Netherlands
# 256                                 Slater (2) - ESI 2  2025           US
# 257                    Flame Dream - Silent Transition  2025  Switzerland
# 401           Leevi And The Leavings - Kadonnut Laakso  2025      Finland
# 402                       UK Subs - Endangered Species  2025      Austria
# 403                      The Rabies (5) - Dumb It Down  2025           US
# 404                   Obituary - Complete Control Tour  2025       Europe
# 405  Orca - 9 Lives / Love Sensation / Distance / A...  2025           UK
# 407                             Various - D.Trance 109  2025      Germany
# 408  Synkro (2) - Jungle Not Jungle Mixtape (1995-2...  2025           UK
# 409                               Nnamdï* - Krazy Karl  2025           US
# 411                 Intouchables* - Beat Of The Street  2025       France
#
#                                   genre  \
# 250                             Hip Hop
# 251  Electronic, Folk, World, & Country
# 252                                Rock
# 253                                Rock
# 254                                Rock
# 255                          Electronic
# 256                        Hip Hop, Pop
# 257                                Rock
# 401               Electronic, Rock, Pop
# 402                                Rock
# 403                                Rock
# 404                                Rock
# 405                          Electronic
# 407                          Electronic
# 408                          Electronic
# 409                          Jazz, Rock
# 411                                Rock
#
#                                         style  \
# 250           Trap, Gangsta, Hardcore Hip-Hop
# 251                             Ambient, Folk
# 252                                Rockabilly
# 253                            Punk, Hardcore
# 254                        Punk, Experimental
# 255                                  Hardcore
# 256               Alt-Pop, Cloud Rap, Pop Rap
# 257                                 Prog Rock
# 401          Pop Rock, Rock & Roll, Synth-pop
# 402                                      Punk
# 403           Indie Rock, Power Pop, Pop Punk
# 404                               Death Metal
# 405                          Hardcore, Jungle
# 407                                    Trance
# 408              Jungle, Ambient, Drum n Bass
# 409  Math Rock, Fusion, Prog Rock, Avantgarde
# 411            Rock & Roll, Punk, Garage Rock
#
#                                                  label  \
# 250                          Waaghals, Soul Trap Music
# 251  Fika Recordings, The Drone Lodge, RedRedPaw, M...
# 252                                     Rollin Records
# 253  Svensk Hardcore Kultur, Audiosiege, Studio Rys...
# 254                                  FHM Records, My45
# 255                                 The Third Movement
# 256                                Fear Of War Records
# 257                                        3VƐ Records
# 401  Svart Records, Oy Svart Musik Ab, Universal Mu...
# 402       Reissued Sounds, Cherry Red, Reissued Sounds
# 403                                       Presidential
# 404                                         Axe Attack
# 405                                        Deep Jungle
# 407                              DJs Present, D.Trance
# 408                                        SK1 Records
# 409                                     Sooper Records
# 411                                   Cameleon Records
#
#                                                 format          catno
# 250      Vinyl, LP, Album, Limited Edition, Remastered          WR030
# 251                           Vinyl, LP, Album, Stereo      FIKA106LP
# 252                   Vinyl, 7", Limited Edition, Mono       RR45-078
# 253                                  Vinyl, 7", 45 RPM        SHK #16
# 254  Vinyl, LP, Album, Limited Edition, Numbered, R...       FHM 0020
# 255                                          File, MP3      T3RDM0440
# 256                                          CD, Album          FOW29
# 257                           Vinyl, LP, Album, Stereo       LP 01007
# 401  Vinyl, LP, Album, Limited Edition, Reissue, St...       SRE202RE
# 402  Vinyl, LP, Album, Limited Edition, Numbered, R...        MICR024
# 403                           Vinyl, LP, Album, Stereo          PRLP1
# 404     Vinyl, LP, Limited Edition, Unofficial Release         AXE013
# 405                                     File, FLAC, EP        DAT 097
# 407                                                 CD  DJP 597 01092
# 408          Cassette, Limited Edition, Mixed, Mixtape       SK1MX002
# 409  Vinyl, LP, Album, Limited Edition, Repress, St...           none
# 411                                   Vinyl, LP, Album        CAME107

# %% [markdown]
# **Data Analysis**

# %%
# finding unique genres
df.genre.unique()
# Out:
# array(['Electronic', 'Electronic, Rock', 'Rock', 'Jazz', 'Non-Music',
#        'Electronic, Hip Hop, Pop, Stage & Screen',
#        'Rock, Folk, World, & Country', 'Rock, Pop', 'Electronic, Pop', '',
#        'Funk / Soul', 'Classical', 'Folk, World, & Country', 'Pop',
#        'Electronic, Rock, Pop', 'Jazz, Rock', 'Hip Hop',
#        'Rock, Pop, Stage & Screen', 'Jazz, Funk / Soul, Stage & Screen',
#        'Electronic, Reggae', 'Reggae',
#        'Electronic, Rock, Funk / Soul, Pop',
#        'Pop, Folk, World, & Country', 'Hip Hop, Folk, World, & Country',
#        'Rock, Blues', 'Rock, Funk / Soul',
#        'Electronic, Jazz, Funk / Soul', 'Rock, Funk / Soul, Pop',
#        'Hip Hop, Pop', 'Jazz, Folk, World, & Country', 'Blues',
#        'Hip Hop, Jazz, Funk / Soul', 'Jazz, Funk / Soul, Pop',
#        'Electronic, Jazz', 'Jazz, Blues', 'Jazz, Funk / Soul',
#        'Electronic, Folk, World, & Country', 'Rock, Blues, Pop',
#        'Electronic, Rock, Funk / Soul, Pop, Folk, World, & Country, Stage & Screen',
#        'Electronic, Rock, Latin', 'Hip Hop, Jazz',
#        'Electronic, Hip Hop, Funk / Soul, Pop', 'Electronic, Latin',
#        'Electronic, Rock, Folk, World, & Country',
#        "Electronic, Pop, Children's"], dtype=object)

# %%
# genre column contains comma-separated string => using this to separate genres
unique_genres = set(
    g.strip()
    for sublist in df['genre'].dropna().apply(lambda x: x.split(','))
    for g in sublist
)
print(unique_genres)
# Out:
# {'', '& Country', 'Electronic', 'Reggae', "Children's", 'Classical', 'Pop', 'Hip Hop', 'Latin', 'Stage & Screen', 'Non-Music', 'Jazz', 'World', 'Funk / Soul', 'Rock', 'Folk', 'Blues'}

# %%
# identify the most common genres
genre_series = df['genre'].dropna().str.split(', ')
all_genres = genre_series.explode()
all_genres.value_counts().head(10)
# Out:
# genre
# Rock              260
# Electronic        140
# Pop                49
# Folk               25
# World              25
# & Country          25
# Jazz               24
# Hip Hop            21
# Funk / Soul        17
# Stage & Screen      7
# Name: count, dtype: int64

# %%
# find the most common genre
df['genre'].str.split(",").explode().str.strip().value_counts().head(1)
# Out:
# genre
# Rock    296
# Name: count, dtype: int64

# %%
#find the least common genre
df['genre'].str.split(",").explode().str.strip().value_counts().tail(1)
# Out:
# genre
# Children's    1
# Name: count, dtype: int64

# %%
df.country.unique()
# Out:
# array(['Italy', 'Portugal', 'France', 'Germany', 'Unknown', 'US',
#        'Denmark', 'Europe', 'Japan', 'Netherlands', 'Canada', 'Greece',
#        'Worldwide', 'UK', 'Spain', 'Belgium', 'Chile', 'Australia',
#        'Austria', 'USA & Europe', 'Finland', 'USA & Canada', 'Sweden',
#        'Poland', 'Brazil', 'UK & US', 'South Korea', 'Norway',
#        'Germany, Austria, & Switzerland', 'UK & Europe', 'Hungary',
#        'Estonia', 'Russia', 'Switzerland', 'Benelux', 'Malaysia',
#        'Czech Republic'], dtype=object)

# %%
df.format.unique()
# Out:
# array(['CD, Album, Limited Edition, Stereo', 'Vinyl, 12"',
#        'Vinyl, LP, Promo, Test Pressing',
#        'Vinyl, LP, Album, Limited Edition, Numbered',
#        'CDr, Album, Limited Edition', 'Vinyl, LP, Album, Reissue',
#        'CD, Album', 'Vinyl, LP, Album', 'Lathe Cut, 12", EP, Stereo',
#        'Vinyl, LP, Album, Limited Edition',
#        'CDr, Album, Limited Edition, Numbered',
#        'Vinyl, 12", 33 ⅓ RPM, EP', 'Vinyl, LP, Album, Test Pressing',
#        'CD, EP', 'File, FLAC, Mixed', 'Vinyl, 12", 45 RPM, Maxi-Single',
#        'Vinyl, LP, 45 RPM, Limited Edition, Numbered',
#        'CD, Album, Limited Edition',
#        'Lathe Cut, LP, 33 ⅓ RPM, Album, Limited Edition, Numbered, Stereo',
#        'CD, Album, Compilation', 'CDr, Album', 'Vinyl, 12", EP',
#        'CD, Album, Stereo',
#        'Memory Stick, AAC, FLAC, MP3, WAV, Compilation, Stereo',
#        'Vinyl, LP, Album, Limited Edition, Stereo',
#        'Vinyl, LP, Album, Stereo', 'CD, Album, Special Edition, Stereo',
#        'Vinyl, LP, Compilation, Test Pressing', 'Vinyl, LP',
#        'Vinyl, LP, Album, Reissue, Remastered', 'File, FLAC, Album',
#        'File, MP3, Album', 'Vinyl, LP, 45 RPM, EP',
#        'Vinyl, 12", 45 RPM, Compilation, Stereo',
#        'Vinyl, 7", 45 RPM, Single', 'Vinyl, 7", 45 RPM, Stereo',
#        'Vinyl, LP, Album, Compilation', 'Vinyl, 7", Single',
#        'Vinyl, 12", Test Pressing',
#        'Vinyl, LP, 45 RPM, EP, Limited Edition',
#        'DVDr, DVD-Video, Mini-Album, Limited Edition, Numbered',
#        'Vinyl, LP, Album, Reissue, Vinyl, LP, Album, Reissue, Vinyl, LP, Album, Reissue, Vinyl, LP, Compilation, Vinyl, 7", 33 ⅓ RPM, Box Set, Compilation, Limited Edition',
#        'Vinyl, LP, Vinyl, LP, Single Sided, All Media, Album, Limited Edition',
#        'Vinyl, LP, Limited Edition, Stereo', 'Cassette, Album',
#        'Vinyl, LP, Reissue, Remastered',
#        'Vinyl, 12", EP, Limited Edition, Numbered, Reissue, Remastered',
#        'Vinyl, LP, Limited Edition, Reissue, Remastered, Stereo',
#        'Vinyl, LP, Stereo', 'Cassette, Limited Edition',
#        'Vinyl, LP, Limited Edition, Numbered', 'CD, EP, Limited Edition',
#        'Vinyl, LP, Unofficial Release',
#        'Vinyl, 12", 45 RPM, Maxi-Single, Stereo',
#        'Vinyl, LP, Limited Edition', 'CD, Album, Reissue, Remastered',
#        'Vinyl, LP, Album, Limited Edition, Reissue',
#        'Vinyl, LP, Album, Reissue, Stereo', 'CD, Mini-Album', 'Vinyl, 7"',
#        'Vinyl, LP, Album, Repress, Special Edition, Stereo',
#        'CD, Album, Limited Edition, Reissue, Remastered, Stereo',
#        'Vinyl, 12", 45 RPM, EP, Limited Edition',
#        'Vinyl, 12", 45 RPM, EP', 'CD, Compilation, Promo, Stereo',
#        'Vinyl, LP, Single Sided, Album, Limited Edition, Numbered',
#        'Vinyl, LP, Compilation',
#        'Cassette, Album, Limited Edition, Numbered, Reissue, Remastered',
#        'Vinyl, 12", 45 RPM',
#        'Vinyl, 12", 33 ⅓ RPM, EP, Limited Edition, Stereo',
#        'Vinyl, LP, Compilation, Limited Edition', 'CD, Album, Reissue',
#        'CD, Compilation, Limited Edition, Numbered, Unofficial Release',
#        'Vinyl, LP, Album, Limited Edition, Reissue, Stereo',
#        'Vinyl, LP, Album, Limited Edition, Numbered, Reissue, Remastered',
#        'CD, Compilation, Reissue, Remastered',
#        'Vinyl, LP, Album, Limited Edition, Reissue, Remastered',
#        'Vinyl, 12", 33 ⅓ RPM, EP, Repress',
#        'Vinyl, LP, Limited Edition, Numbered, Unofficial Release',
#        'Vinyl, LP, Reissue, Remastered, Box Set, Compilation, Limited Edition',
#        'Vinyl, 7", 45 RPM, Single, Limited Edition, Unofficial Release',
#        'CD, Compilation', 'Vinyl, 12", 33 ⅓ RPM, Maxi-Single',
#        'Vinyl, 7", 45 RPM, Single, Limited Edition',
#        'Vinyl, LP, Album, Record Store Day, Reissue, Remastered, Mono',
#        'Vinyl, 12", EP, Limited Edition', 'Vinyl, 7", EP',
#        'CD, Album, Misprint',
#        'Vinyl, LP, Limited Edition, Numbered, Reissue, Remastered',
#        'File, WAV',
#        'Vinyl, LP, Album, Limited Edition, Unofficial Release',
#        'Cassette, Single Sided, Limited Edition, Numbered, Reissue',
#        'CD, Stereo', 'Vinyl, LP, Compilation, Limited Edition, Stereo',
#        'CD, Album, Limited Edition, Reissue',
#        'Vinyl, LP, Album, Limited Edition, Numbered, Reissue, Repress, Stereo',
#        'Vinyl, 7", 45 RPM, EP, Record Store Day',
#        'Cassette, Album, Limited Edition, Reissue',
#        'File, FLAC, Album, Stereo', 'CD, Compilation, Promo, Sampler',
#        'Vinyl, 12", 33 ⅓ RPM',
#        'Vinyl, 12", 33 ⅓ RPM, EP, Limited Edition',
#        'Vinyl, LP, Album, Limited Edition, Remastered',
#        'Vinyl, 7", Limited Edition', 'Vinyl, 7", Limited Edition, Mono',
#        'Vinyl, 7", 45 RPM',
#        'Vinyl, LP, Album, Limited Edition, Numbered, Reissue, Remastered, Stereo',
#        'File, MP3', 'CD, Compilation, Remastered',
#        'Vinyl, LP, Album, Reissue, Remastered, Vinyl, LP, Box Set, Deluxe Edition',
#        'Cassette, EP, Limited Edition',
#        'Vinyl, 12", 33 ⅓ RPM, Limited Edition, Reissue', 'CDr, EP',
#        'Vinyl, LP, Album, Numbered, Stereo', 'Cassette',
#        'CD, Album, CD, Album, Reissue', 'Vinyl, LP, 45 RPM',
#        'Vinyl, LP, Compilation, Unofficial Release',
#        'Cassette, Album, Reissue, Remastered',
#        'Vinyl, LP, Compilation, Stereo',
#        'CD, Album, Limited Edition, Numbered',
#        'Vinyl, LP, Album, Limited Edition, Picture Disc, Reissue',
#        'Lathe Cut, 10", 45 RPM, Limited Edition',
#        'Cassette, Unofficial Release',
#        'Vinyl, LP, Album, Compilation, Reissue, Stereo',
#        'Vinyl, LP, Limited Edition, Unofficial Release, Stereo',
#        'Vinyl, LP, Album, Limited Edition, Repress',
#        'Vinyl, LP, Album, Limited Edition, Repress, Stereo',
#        'Cassette, Album, Limited Edition', 'CDr, Single',
#        'File, FLAC, Compilation, Remastered, Stereo',
#        'CD, DVD, DVD-Video, NTSC, Stereo, All Media, Album',
#        'Vinyl, LP, Reissue', 'Vinyl, 12", Limited Edition',
#        'CD, DVD, Limited Edition, Unofficial Release',
#        'Vinyl, LP, Limited Edition, Picture Disc, Reissue',
#        'Vinyl, LP, Album, Unofficial Release',
#        'CD, Limited Edition, Numbered, Unofficial Release',
#        'File, FLAC, Single', 'Cassette, Album, EP, Limited Edition',
#        'Vinyl, 12", Mini-Album',
#        'Lathe Cut, 12", Limited Edition, Numbered', 'File, WAV, Album',
#        'Cassette, Mini-Album, Limited Edition, Reissue', 'CD',
#        'File, FLAC, Single, Stereo', 'Vinyl, 7", 45 RPM, EP, Stereo',
#        'Vinyl, 7", 45 RPM, Limited Edition',
#        'Vinyl, LP, Vinyl, LP, All Media, Repress',
#        'Cassette, Compilation', 'Vinyl, 12", 45 RPM, EP, Reissue',
#        'Vinyl, LP, Limited Edition, Vinyl, 7", 33 ⅓ RPM',
#        'Lathe Cut, 7", 33 ⅓ RPM, EP', 'CD, Album, Deluxe Edition, Stereo',
#        'File, WAV, Single', 'CDr, Album, Limited Edition, Stereo',
#        'Vinyl, LP, Test Pressing',
#        'Vinyl, 7", 45 RPM, Limited Edition, Numbered, Special Edition',
#        'Vinyl, LP, Album, Limited Edition, Stereo, CD, Stereo',
#        'Vinyl, 7", 45 RPM, EP',
#        'Vinyl, LP, Album, Limited Edition, Numbered, Reissue',
#        'Vinyl, LP, Limited Edition, Unofficial Release', 'File, FLAC, EP',
#        'Cassette, Limited Edition, Mixed, Mixtape',
#        'CDr, Mini-Album, Stereo',
#        'Vinyl, LP, Album, Limited Edition, Numbered, Stereo',
#        'Vinyl, 10", 45 RPM',
#        'Vinyl, LP, 45 RPM, Album, Limited Edition, Reissue, Special Edition',
#        'Vinyl, LP, EP, Limited Edition, Stereo', 'File, WAV, EP',
#        'CDr, Limited Edition', 'Cassette, EP',
#        'Cassette, Single Sided, Promo, Sampler',
#        'CD, Compilation, Limited Edition, Remastered',
#        'Cassette, Single Sided, Compilation, Limited Edition, Numbered',
#        'CD, Remastered',
#        'Vinyl, LP, Album, Limited Edition, Promo, Unofficial Release',
#        'Vinyl, 12", 45 RPM, Album, Limited Edition, Reissue, Remastered',
#        'Vinyl, LP, Album, Repress', 'Vinyl, 12", 33 ⅓ RPM, EP, Stereo',
#        'Vinyl, 7", 33 ⅓ RPM, EP', 'Vinyl, LP, 45 RPM, Album',
#        'Vinyl, LP, Compilation, Remastered',
#        'Cassette, Limited Edition, Numbered',
#        'Vinyl, LP, Limited Edition, Reissue, Remastered',
#        'Vinyl, 12", 45 RPM, EP, Limited Edition, Reissue, Stereo',
#        'Vinyl, LP, Vinyl, LP, Single Sided, Etched, All Media, Album, Reissue',
#        'File, FLAC',
#        'Vinyl, LP, Album, Limited Edition, Numbered, Picture Disc',
#        'CD, EP, Reissue',
#        'Cassette, Album, Limited Edition, Numbered, Stereo',
#        'Vinyl, LP, Limited Edition, Numbered, Remastered',
#        'Box Set, Compilation, CD'], dtype=object)

# %%
# format column contains comma-separated string => using this to separate format
unique_formats = set(
    g.strip()
    for sublist in df['format'].dropna().apply(lambda x: x.split(','))
    for g in sublist
)
print(unique_genres)
# Out:
# {'Album', 'Vinyl', 'Mixtape', 'Sampler', 'Record Store Day', '12"', 'DVDr', 'DVD-Video', 'Single', 'MP3', 'Box Set', 'Test Pressing', 'All Media', 'Memory Stick', 'Special Edition', 'WAV', 'Maxi-Single', 'Promo', 'Unofficial Release', 'Cassette', 'Mini-Album', 'NTSC', '45 RPM', 'AAC', '10"', 'DVD', 'Compilation', 'Etched', 'EP', 'Misprint', 'Reissue', 'CDr', 'Remastered', 'Lathe Cut', 'Mixed', 'FLAC', 'Mono', 'LP', 'CD', 'Repress', 'Single Sided', 'Numbered', '33 ⅓ RPM', 'Deluxe Edition', 'Picture Disc', 'File', '7"', 'Stereo', 'Limited Edition'}

# %%
# find top 10 most popular format
df['format'].value_counts().head(10)
# Out:
# format
# CD, Album                            35
# Vinyl, LP, Album                     33
# Vinyl, LP, Album, Stereo             18
# Vinyl, LP, Album, Limited Edition    16
# Vinyl, LP                             9
# CDr, Album, Limited Edition           9
# Vinyl, LP, Album, Reissue             9
# CD, Album, Stereo                     9
# Vinyl, LP, Limited Edition            8
# CD, Album, Limited Edition            7
# Name: count, dtype: int64

# %%
# find the top 10 common style
style_series = df['style'].dropna().str.split(', ')
all_styles = style_series.explode()
all_styles.value_counts().head(10)
# Out:
# style
# Punk                43
# Black Metal         32
# Hardcore            29
# Experimental        25
# Ambient             23
# Hard Rock           21
# Techno              21
# Indie Rock          20
# Death Metal         18
# Psychedelic Rock    17
# Name: count, dtype: int64

# %%
# identify strong genre–style relationships
from collections import Counter
pairs = []

for _, row in df.dropna(subset=['genre','style']).iterrows():
    genres = row['genre'].split(', ')
    styles = row['style'].split(', ')
    for g in genres:
        for s in styles:
            pairs.append((g, s))

pair_counts = Counter(pairs)
pair_counts.most_common(20)
# Out:
# [(('Rock', 'Punk'), 43),
#  (('Rock', 'Black Metal'), 32),
#  (('Electronic', 'Ambient'), 23),
#  (('Electronic', 'Techno'), 21),
#  (('Rock', 'Hard Rock'), 21),
#  (('Rock', 'Indie Rock'), 20),
#  (('Electronic', 'Experimental'), 19),
#  (('Rock', 'Death Metal'), 18),
#  (('Rock', 'Hardcore'), 17),
#  (('Rock', 'Psychedelic Rock'), 17),
#  (('Rock', 'Alternative Rock'), 17),
#  (('Electronic', 'Synth-pop'), 14),
#  (('Rock', 'Prog Rock'), 14),
#  (('Electronic', 'House'), 12),
#  (('Rock', 'Experimental'), 12),
#  (('Electronic', 'Hardcore'), 12),
#  (('Rock', 'Heavy Metal'), 12),
#  (('Rock', 'Garage Rock'), 12),
#  (('Electronic', 'Drone'), 11),
#  (('Rock', 'Pop Rock'), 11)]

# %%
# find all the labels in countries

label_series = df['label'].dropna()
label_series = label_series.str.split(', ')
labels_exploded = label_series.explode()   # explode into one label per row

# match countries
label_country = df.loc[labels_exploded.index, ['country']].copy()
label_country['label'] = labels_exploded.values

# count labels per country
label_counts = (
    label_country
    .groupby(['country', 'label'])
    .size()
    .reset_index(name='count')
)
print(label_counts.head(30))
# Out:
#       country                          label  count
# 0   Australia             Blow Blood Records      2
# 1   Australia               Coolin' By Sound      1
# 2   Australia                Diggers Factory      1
# 3   Australia              Lilystars Records      1
# 4   Australia           Nettwerk Music Group      1
# 5   Australia                        Rizzwax      1
# 6     Austria                     Cherry Red      2
# 7     Austria            Dubbing Sun Records      1
# 8     Austria                         Födweg      1
# 9     Austria                 Napalm Records      1
# 10    Austria                Reissued Sounds      4
# 11    Belgium                     Hoot Music      1
# 12    Belgium             Klankhaven Records      1
# 13    Belgium                Reality Records      1
# 14    Belgium          Resonanz Distribution      1
# 15    Benelux           Petrol Candy Records      1
# 16    Benelux                    RSD Records      1
# 17    Benelux                Record Industry      1
# 18     Brazil                  Amara Records      1
# 19     Brazil               Amigues Do Vinil      1
# 20     Brazil               BC Noise Records      1
# 21     Brazil               Blizzard Records      1
# 22     Brazil                   Brado Distro      1
# 23     Brazil                  Brado Records      1
# 24     Brazil                  Cabra Macabra      1
# 25     Brazil                 Carniça Distro      1
# 26     Brazil  Cosmonauta Submerso Gravações      1
# 27     Brazil           Cospe Fogo Gravações      1
# 28     Brazil              Desenhos Malditos      1
# 29     Brazil                 Dynamo Records      1

# %%
# save the data in xlxs file for using in Tableau
df.to_excel("discogs_music.xlsx", index=False)

# %% [markdown]
# **Database Storage**

# %%
import mysql.connector
from mysql.connector import Error

def test_mysql_connection(host_name, user_name, user_password):
    conn = None
    try:
        conn = mysql.connector.connect(
            host=host_name,
            user=user_name,
            passwd=user_password
        )
        if conn.is_connected():
            print('Connection to MySQL database was successful')
    except Error as e:
        print(f"Error: '{e}'")
    finally:
        if conn.is_connected():
            conn.close()
            print('Connection to MySQL database is closed.')

# Test the function
test_mysql_connection("localhost", "root", "")
# Out:
# Connection to MySQL database was successful
# Connection to MySQL database is closed.

# %%
# !pip install pymysql
from sqlalchemy import create_engine
import pymysql

# Create SQLAlchemy engine connection
engine = create_engine("mysql+pymysql://root:@localhost:3306/Dsci105")  # DB name = Dsci105

# Save DataFrame to MySQL table
df.to_sql(name="discogs_music", con=engine, if_exists="replace", index=False)

print("Data successfully saved into MySQL!")
# Out:
# Requirement already satisfied: pymysql in /opt/anaconda3/lib/python3.12/site-packages (1.1.2)
# Data successfully saved into MySQL!

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql mysql+pymysql://root:@localhost:3306/Dsci105

# %%
# %%sql
# SHOW TABLES;
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/Dsci105'
# 5 rows affected.
# +-------------------+
# | Tables_in_dsci105 |
# +-------------------+
# |       books       |
# |     customers     |
# |   discogs_music   |
# |    transactions   |
# |       Users       |
# +-------------------+

# %%
# %%sql
# DESC discogs_music;
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/Dsci105'
# 8 rows affected.
# +---------+------+------+-----+---------+-------+
# |  Field  | Type | Null | Key | Default | Extra |
# +---------+------+------+-----+---------+-------+
# |  title  | text | YES  |     |   None  |       |
# |   year  | text | YES  |     |   None  |       |
# | country | text | YES  |     |   None  |       |
# |  genre  | text | YES  |     |   None  |       |
# |  style  | text | YES  |     |   None  |       |
# |  label  | text | YES  |     |   None  |       |
# |  format | text | YES  |     |   None  |       |
# |  catno  | text | YES  |     |   None  |       |
# +---------+------+------+-----+---------+-------+

# %%
# %%sql
# SELECT COUNT(*) AS total_releases
# FROM discogs_music;
# # find total release in the table
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/Dsci105'
# 1 rows affected.
# +----------------+
# | total_releases |
# +----------------+
# |      443       |
# +----------------+

# %%
# %%sql
# SELECT genre, COUNT(*) AS count
# FROM discogs_music
# WHERE genre IS NOT NULL AND genre <> ''
# GROUP BY genre
# ORDER BY count DESC
# LIMIT 10;
# # find top 10 most common genre
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/Dsci105'
# 10 rows affected.
# +------------------------------+-------+
# |            genre             | count |
# +------------------------------+-------+
# |             Rock             |  204  |
# |          Electronic          |   96  |
# |          Rock, Pop           |   14  |
# | Rock, Folk, World, & Country |   12  |
# |           Hip Hop            |   12  |
# |       Electronic, Rock       |   12  |
# |             Jazz             |   10  |
# |             Pop              |   8   |
# |    Folk, World, & Country    |   6   |
# |       Electronic, Pop        |   6   |
# +------------------------------+-------+
# Truncated to displaylimit of 10.

# %%
# %%sql
# SELECT style, COUNT(*) AS count
# FROM discogs_music
# WHERE style IS NOT NULL AND style <> ''
# GROUP BY style
# ORDER BY count DESC
# LIMIT 10;
# # find top 10 most common style
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/Dsci105'
# 10 rows affected.
# +------------------+-------+
# |      style       | count |
# +------------------+-------+
# |   Black Metal    |   20  |
# |       Punk       |   14  |
# |    Hard Rock     |   14  |
# |     Hardcore     |   11  |
# |  Ambient, Drone  |   10  |
# |    Prog Rock     |   6   |
# |      Techno      |   6   |
# | Alternative Rock |   6   |
# |   Death Metal    |   6   |
# |   Heavy Metal    |   5   |
# +------------------+-------+
# Truncated to displaylimit of 10.

# %%
# %%sql
# SELECT year, COUNT(*) AS releases_per_year
# FROM discogs_music
# WHERE year IS NOT NULL AND year <> ''
# GROUP BY year
# ORDER BY year;
# # number of release per year
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/Dsci105'
# 2 rows affected.
# +------+-------------------+
# | year | releases_per_year |
# +------+-------------------+
# | 2025 |        375        |
# | 2026 |         68        |
# +------+-------------------+

# %%
# %%sql
# SELECT format, COUNT(*) AS format_count
# FROM discogs_music
# WHERE format IS NOT NULL AND format <> ''
# GROUP BY format
# ORDER BY format_count DESC;
# # distribution of format
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/Dsci105'
# 193 rows affected.
# +-----------------------------------+--------------+
# |               format              | format_count |
# +-----------------------------------+--------------+
# |             CD, Album             |      35      |
# |          Vinyl, LP, Album         |      33      |
# |      Vinyl, LP, Album, Stereo     |      18      |
# | Vinyl, LP, Album, Limited Edition |      16      |
# |    CDr, Album, Limited Edition    |      9       |
# |     Vinyl, LP, Album, Reissue     |      9       |
# |         CD, Album, Stereo         |      9       |
# |             Vinyl, LP             |      9       |
# |     Vinyl, LP, Limited Edition    |      8       |
# |     CD, Album, Limited Edition    |      7       |
# +-----------------------------------+--------------+
# Truncated to displaylimit of 10.

# %%
# %%sql
# SELECT country, COUNT(*) AS releases_per_country
# FROM discogs_music
# WHERE country IS NOT NULL AND country <> ''
# GROUP BY country
# ORDER BY releases_per_country DESC
# LIMIT 10;
# # find top 10 country by number of release
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/Dsci105'
# 10 rows affected.
# +-------------+----------------------+
# |   country   | releases_per_country |
# +-------------+----------------------+
# |      US     |          84          |
# |   Germany   |          58          |
# |      UK     |          50          |
# |    France   |          26          |
# |    Europe   |          25          |
# | Netherlands |          25          |
# |    Italy    |          24          |
# |   Unknown   |          14          |
# |  Worldwide  |          12          |
# |    Japan    |          9           |
# +-------------+----------------------+
# Truncated to displaylimit of 10.

# %%
# %%sql
# SELECT country, genre, COUNT(*) AS count_releases
# FROM discogs_music
# WHERE country = 'US'
#   AND genre IS NOT NULL AND genre <> ''
# GROUP BY country, genre
# ORDER BY count_releases DESC;
# # find all genres that released in US
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/Dsci105'
# 22 rows affected.
# +---------+------------------------------------+----------------+
# | country |               genre                | count_releases |
# +---------+------------------------------------+----------------+
# |    US   |                Rock                |       42       |
# |    US   |             Electronic             |       8        |
# |    US   |                Jazz                |       5        |
# |    US   |             Rock, Pop              |       4        |
# |    US   |       Folk, World, & Country       |       3        |
# |    US   |          Electronic, Rock          |       3        |
# |    US   |             Non-Music              |       2        |
# |    US   |            Hip Hop, Pop            |       2        |
# |    US   |             Jazz, Rock             |       2        |
# |    US   | Electronic, Folk, World, & Country |       1        |
# +---------+------------------------------------+----------------+
# Truncated to displaylimit of 10.

# %%
# %%sql
# SELECT country, genre, COUNT(*) AS count_releases
# FROM discogs_music
# WHERE country = 'UK'
#   AND genre IS NOT NULL AND genre <> ''
# GROUP BY country, genre
# ORDER BY count_releases DESC;
# # find all genres that released in UK
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/Dsci105'
# 13 rows affected.
# +---------+------------------------------------+----------------+
# | country |               genre                | count_releases |
# +---------+------------------------------------+----------------+
# |    UK   |                Rock                |       21       |
# |    UK   |             Electronic             |       17       |
# |    UK   | Electronic, Folk, World, & Country |       2        |
# |    UK   |     Rock, Pop, Stage & Screen      |       1        |
# |    UK   |         Electronic, Reggae         |       1        |
# |    UK   |    Rock, Folk, World, & Country    |       1        |
# |    UK   |       Folk, World, & Country       |       1        |
# |    UK   |             Classical              |       1        |
# |    UK   |          Electronic, Jazz          |       1        |
# |    UK   |          Electronic, Pop           |       1        |
# +---------+------------------------------------+----------------+
# Truncated to displaylimit of 10.

# %%
# %%sql
# SELECT title, year, country, genre, format, label
# FROM discogs_music
# WHERE genre LIKE '%Rock%'
#   AND format LIKE '%Vinyl%'
# ORDER BY year DESC;
# # find Rock genre release on Vinyl format
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/Dsci105'
# 170 rows affected.
# +---------------------------------------------+------+---------+------------------------------+---------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |                    title                    | year | country |            genre             |                    format                   |                                                                                                    label                                                                                                    |
# +---------------------------------------------+------+---------+------------------------------+---------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |       Periode - Grapes Of Nothingness       | 2026 | Germany |       Electronic, Rock       | Vinyl, LP, Album, Limited Edition, Numbered |     Karlrecords, Periklas Series, HeyRec.Org, HeyRec.Org, Paulick Saal Berlin, Paulick Saal Berlin, Spatialtone, Barb32, Feuer Und Flamme Für Berlin Studio, Barb32, Feuer Und Flamme Für Berlin Studio     |
# |             Mesarthim - Isolate             | 2026 |  Italy  |             Rock             |          Vinyl, LP, Album, Reissue          |                                                              Avantgarde Music, Hard & Heavy, Avantgarde Music, Avantgarde Music, SST GmbH, MPO                                                              |
# |     Agnostic Front - Echoes In Eternity     | 2026 |  Europe |             Rock             |      Vinyl, LP, Album, Limited Edition      |                                                                                Reigning Phoenix Music, Reigning Phoenix Music                                                                               |
# |             Golden Spike - blerk            | 2026 |  Japan  | Rock, Folk, World, & Country |       Vinyl, LP, Album, Test Pressing       |                                                                                      Leafblower Records, Sam Beer Sound                                                                                     |
# |            Thy Catafalque - Naiv            | 2026 |  Italy  |             Rock             |          Vinyl, LP, Album, Reissue          |                                  Season Of Mist, DeAgostini, Sony Music, Hard & Heavy, DeAgostini, Season Of Mist, Season Of Mist, Sony Music Entertainment, SST GmbH, MPO                                  |
# |         Gunstig Junker - Vi Mot Dom         | 2026 |  Sweden |             Rock             |               Vinyl, LP, Album              |                                                                       Dala Destroi Records, Dala Destroi Records, Dala Destroi Records                                                                      |
# | Ran (7) - Beautiful Songs For Ugly Children | 2026 |    UK   |             Rock             |               Vinyl, LP, Album              |                                                                                       Boss Tuneage, Boss Tuneage Retro                                                                                      |
# |               Wet Tuna - Vast               | 2026 |    US   |             Rock             |      Vinyl, LP, Album, Limited Edition      |                                          Three Lobed Recordings, Sweet Pond, Fort Future, Coney Island Audio, Green Machines MkII, Smashed Plastic Record Pressing                                          |
# |             Abbath (2) - Abbath             | 2026 |  Italy  |             Rock             |          Vinyl, LP, Album, Reissue          | Season Of Mist, DeAgostini, Sony Music, Hard & Heavy, DeAgostini, Season Of Mist, Sony Music Entertainment, Bergen Lydstudio, Dug Out Studio, Dug Out Studio, Dug Out Studio, Dug Out Studio, SST GmbH, MPO |
# |       Monumentum - In Absentia Christi      | 2026 |  Italy  |       Electronic, Rock       |          Vinyl, LP, Album, Reissue          |                                                        Avantgarde Music, Hard & Heavy, Avantgarde Music, Avantgarde Music, Bips Studio, SST GmbH, MPO                                                       |
# +---------------------------------------------+------+---------+------------------------------+---------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# Truncated to displaylimit of 10.
